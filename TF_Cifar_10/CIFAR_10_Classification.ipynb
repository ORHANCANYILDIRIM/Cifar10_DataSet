# %%
import tensorflow as tf

# Display the version
print(tf.__version__)

# other imports
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
import os
# Out:
# 2.18.0

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10

# Distribute it to train and test set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %%
# Reduce pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0

# flatten the label values
y_train, y_test = y_train.flatten(), y_test.flatten()

# %%
# visualize data by plotting images
fig, ax = plt.subplots(5, 5)
k = 0

for i in range(5):
	for j in range(5):
		ax[i][j].imshow(x_train[k], aspect='auto')
		k += 1



os.makedirs("png", exist_ok=True)
plt.savefig(os.path.join("png", "class_samples.png"))
plt.show()

# %%
# number of classes
K = len(set(y_train))

# calculate total number of classes
# for output layer
print("number of classes:", K)

# Build the model using the functional API
# input layer
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)
x = Dropout(0.2)(x)

# Hidden layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)

# last hidden layer i.e.. output layer
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# model description
model.summary()
# Out:
# number of classes: 10
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,397,226 (9.14 MB)
#  Trainable params: 2,396,330 (9.14 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# Compile
model.compile(optimizer='adam',
			loss='sparse_categorical_crossentropy',
			metrics=['accuracy'])

# %%
# Fit
r = model.fit(
x_train, y_train, validation_data=(x_test, y_test), epochs=50)
# Out:
# Epoch 1/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 117s 72ms/step - accuracy: 0.4561 - loss: 1.6730 - val_accuracy: 0.6577 - val_loss: 0.9599
# Epoch 2/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 94s 60ms/step - accuracy: 0.6945 - loss: 0.8785 - val_accuracy: 0.7046 - val_loss: 0.8504
# Epoch 3/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 95s 61ms/step - accuracy: 0.7597 - loss: 0.6981 - val_accuracy: 0.7465 - val_loss: 0.7169
# Epoch 4/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 96s 61ms/step - accuracy: 0.8010 - loss: 0.5791 - val_accuracy: 0.7386 - val_loss: 0.8069
# Epoch 5/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 59ms/step - accuracy: 0.8321 - loss: 0.4902 - val_accuracy: 0.7863 - val_loss: 0.6397
# Epoch 6/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 91s 58ms/step - accuracy: 0.8622 - loss: 0.4040 - val_accuracy: 0.7715 - val_loss: 0.7165
# Epoch 7/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 91s 58ms/step - accuracy: 0.8816 - loss: 0.3409 - val_accuracy: 0.8129 - val_loss: 0.6176
# Epoch 8/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 99s 64ms/step - accuracy: 0.9014 - loss: 0.2813 - val_accuracy: 0.8136 - val_loss: 0.6068
# Epoch 9/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 103s 66ms/step - accuracy: 0.9166 - loss: 0.2394 - val_accuracy: 0.7773 - val_loss: 0.7378
# Epoch 10/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 104s 66ms/step - accuracy: 0.9279 - loss: 0.2083 - val_accuracy: 0.8156 - val_loss: 0.6534
# Epoch 11/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 102s 66ms/step - accuracy: 0.9338 - loss: 0.1914 - val_accuracy: 0.8166 - val_loss: 0.6669
# Epoch 12/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 105s 67ms/step - accuracy: 0.9439 - loss: 0.1621 - val_accuracy: 0.8157 - val_loss: 0.6952
# Epoch 13/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 103s 66ms/step - accuracy: 0.9511 - loss: 0.1463 - val_accuracy: 0.8230 - val_loss: 0.6918
# Epoch 14/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 104s 67ms/step - accuracy: 0.9533 - loss: 0.1370 - val_accuracy: 0.8226 - val_loss: 0.7073
# Epoch 15/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 94s 60ms/step - accuracy: 0.9562 - loss: 0.1307 - val_accuracy: 0.8256 - val_loss: 0.7202
# Epoch 16/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 91s 58ms/step - accuracy: 0.9609 - loss: 0.1132 - val_accuracy: 0.8151 - val_loss: 0.7716
# Epoch 17/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 90s 58ms/step - accuracy: 0.9628 - loss: 0.1135 - val_accuracy: 0.8173 - val_loss: 0.8077
# Epoch 18/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 94s 60ms/step - accuracy: 0.9639 - loss: 0.1095 - val_accuracy: 0.8244 - val_loss: 0.7473
# Epoch 19/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 92s 59ms/step - accuracy: 0.9678 - loss: 0.0949 - val_accuracy: 0.8237 - val_loss: 0.7989
# Epoch 20/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 91s 58ms/step - accuracy: 0.9719 - loss: 0.0847 - val_accuracy: 0.8289 - val_loss: 0.7483
# Epoch 21/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 92s 59ms/step - accuracy: 0.9712 - loss: 0.0878 - val_accuracy: 0.8321 - val_loss: 0.7833
# Epoch 22/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 91s 58ms/step - accuracy: 0.9731 - loss: 0.0807 - val_accuracy: 0.8233 - val_loss: 0.8250
# Epoch 23/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 91s 58ms/step - accuracy: 0.9747 - loss: 0.0789 - val_accuracy: 0.8309 - val_loss: 0.7521
# Epoch 24/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 102s 65ms/step - accuracy: 0.9750 - loss: 0.0742 - val_accuracy: 0.8194 - val_loss: 0.8905
# Epoch 25/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 98s 63ms/step - accuracy: 0.9761 - loss: 0.0690 - val_accuracy: 0.8317 - val_loss: 0.8104
# Epoch 26/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 94s 60ms/step - accuracy: 0.9786 - loss: 0.0686 - val_accuracy: 0.8346 - val_loss: 0.7621
# Epoch 27/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 91s 58ms/step - accuracy: 0.9788 - loss: 0.0630 - val_accuracy: 0.8345 - val_loss: 0.7878
# Epoch 28/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 95s 61ms/step - accuracy: 0.9796 - loss: 0.0628 - val_accuracy: 0.8304 - val_loss: 0.8902
# Epoch 29/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 95s 60ms/step - accuracy: 0.9795 - loss: 0.0607 - val_accuracy: 0.8367 - val_loss: 0.8034
# Epoch 30/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 94s 60ms/step - accuracy: 0.9803 - loss: 0.0619 - val_accuracy: 0.8323 - val_loss: 0.8468
# Epoch 31/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 95s 61ms/step - accuracy: 0.9799 - loss: 0.0599 - val_accuracy: 0.8176 - val_loss: 0.9295
# Epoch 32/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 92s 59ms/step - accuracy: 0.9820 - loss: 0.0557 - val_accuracy: 0.8223 - val_loss: 0.7850
# Epoch 33/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 92s 59ms/step - accuracy: 0.9826 - loss: 0.0576 - val_accuracy: 0.8381 - val_loss: 0.8194
# Epoch 34/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 59ms/step - accuracy: 0.9835 - loss: 0.0493 - val_accuracy: 0.8331 - val_loss: 0.7892
# Epoch 35/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 92s 59ms/step - accuracy: 0.9828 - loss: 0.0534 - val_accuracy: 0.8395 - val_loss: 0.8820
# Epoch 36/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 94s 60ms/step - accuracy: 0.9838 - loss: 0.0482 - val_accuracy: 0.8332 - val_loss: 0.9480
# Epoch 37/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 59ms/step - accuracy: 0.9835 - loss: 0.0510 - val_accuracy: 0.8369 - val_loss: 0.8814
# Epoch 38/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 60ms/step - accuracy: 0.9844 - loss: 0.0488 - val_accuracy: 0.8355 - val_loss: 0.8949
# Epoch 39/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 59ms/step - accuracy: 0.9854 - loss: 0.0456 - val_accuracy: 0.8215 - val_loss: 0.8670
# Epoch 40/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 60ms/step - accuracy: 0.9862 - loss: 0.0430 - val_accuracy: 0.8311 - val_loss: 0.9883
# Epoch 41/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 60ms/step - accuracy: 0.9839 - loss: 0.0512 - val_accuracy: 0.8365 - val_loss: 0.9553
# Epoch 42/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 59ms/step - accuracy: 0.9862 - loss: 0.0440 - val_accuracy: 0.8332 - val_loss: 0.9055
# Epoch 43/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 59ms/step - accuracy: 0.9869 - loss: 0.0403 - val_accuracy: 0.8255 - val_loss: 0.9545
# Epoch 44/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 59ms/step - accuracy: 0.9855 - loss: 0.0451 - val_accuracy: 0.8372 - val_loss: 0.8834
# Epoch 45/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 60ms/step - accuracy: 0.9872 - loss: 0.0405 - val_accuracy: 0.8382 - val_loss: 0.8474
# Epoch 46/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 60ms/step - accuracy: 0.9857 - loss: 0.0438 - val_accuracy: 0.8350 - val_loss: 0.8846
# Epoch 47/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 94s 60ms/step - accuracy: 0.9888 - loss: 0.0383 - val_accuracy: 0.8336 - val_loss: 0.8319
# Epoch 48/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 94s 60ms/step - accuracy: 0.9852 - loss: 0.0431 - val_accuracy: 0.8334 - val_loss: 0.8156
# Epoch 49/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 60ms/step - accuracy: 0.9871 - loss: 0.0386 - val_accuracy: 0.8391 - val_loss: 0.8651
# Epoch 50/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 93s 60ms/step - accuracy: 0.9882 - loss: 0.0362 - val_accuracy: 0.8381 - val_loss: 0.8609

# %%
# Fit with data augmentation
# Note: if you run this AFTER calling
# the previous model.fit()
# it will CONTINUE training where it left off
batch_size = 32
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(
width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

train_generator = data_generator.flow(x_train, y_train, batch_size)
steps_per_epoch = x_train.shape[0] // batch_size

r = model.fit(train_generator, validation_data=(x_test, y_test),
			steps_per_epoch=steps_per_epoch, epochs=10)
# Out:
# C:\Users\Orhan\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 110s 70ms/step - accuracy: 0.8104 - loss: 0.6170 - val_accuracy: 0.8279 - val_loss: 0.5294
# Epoch 2/10
#    1/1562 ━━━━━━━━━━━━━━━━━━━━ 1:55 74ms/step - accuracy: 0.9688 - loss: 0.2261
# C:\Users\Orhan\AppData\Local\Programs\Python\Python310\lib\contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9688 - loss: 0.2261 - val_accuracy: 0.8279 - val_loss: 0.5307
# Epoch 3/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 123s 79ms/step - accuracy: 0.8511 - loss: 0.4541 - val_accuracy: 0.8423 - val_loss: 0.5104
# Epoch 4/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9062 - loss: 0.3118 - val_accuracy: 0.8414 - val_loss: 0.5146
# Epoch 5/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 110s 71ms/step - accuracy: 0.8630 - loss: 0.4148 - val_accuracy: 0.8485 - val_loss: 0.4663
# Epoch 6/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8750 - loss: 0.5917 - val_accuracy: 0.8477 - val_loss: 0.4672
# Epoch 7/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 109s 69ms/step - accuracy: 0.8707 - loss: 0.3883 - val_accuracy: 0.8549 - val_loss: 0.4610
# Epoch 8/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8750 - loss: 0.3754 - val_accuracy: 0.8543 - val_loss: 0.4603
# Epoch 9/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 112s 72ms/step - accuracy: 0.8780 - loss: 0.3595 - val_accuracy: 0.8444 - val_loss: 0.4812
# Epoch 10/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9062 - loss: 0.2964 - val_accuracy: 0.8451 - val_loss: 0.4814

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc', color='red')
plt.plot(r.history['val_accuracy'], label='val_acc', color='green')
plt.legend()
plt.savefig('png/accuracy_plot.png')

# %%
# label mapping

labels = '''airplane automobile bird cat deer dog frog horse ship truck'''.split()

# select the image from our test dataset
image_number = 0

# display the image
plt.imshow(x_test[image_number])

# load the image in an array
n = np.array(x_test[image_number])

# reshape it
p = n.reshape(1, 32, 32, 3)

# pass in the network for prediction and
# save the predicted label
predicted_label = labels[model.predict(p).argmax()]

# load the original label
original_label = labels[y_test[image_number]]

# display the result
print("Original label is {} and predicted label is {}".format(
	original_label, predicted_label))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# Original label is cat and predicted label is cat

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Model tahminlerini yap
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # tahmin edilen sınıfları al

# Confusion matrix hesapla
cm = confusion_matrix(y_test, y_pred_classes)

# Confusion matrix görselleştirme
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.savefig('png/Confusion-Matrix.png')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step

# %%
# "results" klasörünün varlığını kontrol et ve yoksa oluştur
save_dir = "results"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Modeli "results" klasörüne kaydet
model_save_path = os.path.join(save_dir, 'Cifar-10_results.keras')  # Keras formatını tercih edin
model.save(model_save_path)

print(f"Model başarıyla şu konuma kaydedildi: {model_save_path}")
# Out:
# Model başarıyla şu konuma kaydedildi: results\Cifar-10_results.keras
